# %% [markdown]
# # 02 - Seasonal-Naive Baseline Model Testing (D3)
#
# This notebook evaluates baseline demand forecasting models (seasonal-naive, moving average) against processed datasets to establish benchmark metrics.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics import mean_absolute_error, mean_squared_error

PROCESSED_DATA_DIR = Path("../data/processed")
