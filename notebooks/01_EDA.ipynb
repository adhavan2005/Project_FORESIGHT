# %% [markdown]
# # 01 - Exploratory Data Analysis & Data Quality Checks (D2)
#
# This notebook performs exploratory data analysis (EDA) and data quality verification across:
# - `sales_daily`
# - `sku_master`
# - `calendar`
# - `inventory_snapshots`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

RAW_DATA_DIR = Path("../data/raw")
PROCESSED_DATA_DIR = Path("../data/processed")
